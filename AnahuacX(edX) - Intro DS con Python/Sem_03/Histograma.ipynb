# %% [markdown]
# # Histograma
#
# <p style='text-align: justify;'>El <b><font color = green>histograma</font></b> es la representación visual de la distribución de los datos a lo largo del intervalo continuo de la variable que se está analizando. El histograma se compone por un conjunto de barras que representan la frecuencia en que aparece un dato dentro diferentes subintervalos de la variable analizada. Los histogramas nos permiten encontrar de manera visual estimaciones acerca de la concentración de los datos, además nos permite observar si existen vacíos en la distribución o valores inusuales.</p>
# <br>
# <center><img src="img/Hist1.png" width = "70%"></center>
# <br>
# <p style='text-align: justify;'>En nuestro primer ejemplo de histogramas, representamos las alturas de ochocientos alumnos, nuestro histograma evidencia que la mayoría de los alumnos tiene una altura cercana a 1.70 metros y que muy pocos alumnos presentan estaturas menores a 1.50 metros o mayores a 1.85 metros. En este ejemplo nuestro histograma se asemeja mucho a una gráfica típica del área de estadística conocida como la distribución normal.</p>
# <br>
# <center><img src="img/Hist2.png" width = "70%"></center>
# <br>
# <p style='text-align: justify;'>La distribución normal, es capaz de representar muchos conjuntos de datos de diferentes áreas del conocimiento o de fenómenos de la naturaleza, pero no es la única distribución que existe. Los histogramas también son útiles para darnos una visión aproximada de la distribución que rige a nuestra población y nos permite construir nuestras propias reglas empíricas producto de la constante observación de los datos con los que trabajamos.</p>
# <br>
# <center><img src="img/Hist3.png" width = "70%"></center>
# ***

# %%
import pandas as pd

# %% [markdown]
# Heart Disease UCI Cleveland
# <br>
# https://www.kaggle.com/ronitf/heart-disease-uci

# %%
df = pd.read_csv("data/heart/heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df['chol']) # chol, abreviación de Colesterol
plt.show()

# %%
plt.hist(df['chol'],bins=20) # 20 intervalos
plt.show()

# %%
plt.hist(df['chol'],bins=5) # 5 intervalos
plt.show()

# %%
plt.hist(df['chol'],bins=20,histtype='step') # Solo el borde
plt.show()

# %%
plt.hist(df['chol'],bins=20,orientation='horizontal')
plt.show()

# %%
plt.hist(df['chol'],bins=20,alpha=0.5)
plt.hist(df['trestbps'],bins=10,alpha=0.5)
plt.show()

# %%
plt.hist(df['chol'],bins=20,alpha=0.5,label='chol')
plt.hist(df['trestbps'],bins=10,alpha=0.5,label='trestbps')
plt.legend()

# %%
#!pip3 install seaborn
#!python3.13 -m pip install --upgrade pip

# %%
import seaborn as sns
sns.displot(df['chol'],kde=False) # kde = false, nos quita la distribución
                                  # el ejemplo por default traia la funcion distplot
                                  # pero ya está descontinuada, la cambie a displot

# %%
sns.displot(df['chol'], kde=True, rug=True) # rug nos muestra como se 
                                            # concentran los datos

# %%
sns.jointplot(x="thalach", y="chol", data=df) # nos gráfica 2 variables

# %%
sns.jointplot(x="thalach", y="chol",kind='hex', data=df)

# %%
#sns.set()      # OBSOLETA
sns.set_theme()
sns.jointplot(x="thalach", y="chol",kind='hex', data=df)
